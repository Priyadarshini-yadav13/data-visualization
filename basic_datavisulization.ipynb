# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyadarshini-yadav13/data-visualization/blob/main/basic_datavisulization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are four basic libraries used in python
# Numpy-this library is used for numerical python.the datastructure for this library is numpy array.
# Python-is used for data wrangling and data cleaning.
# Matplotlib-is used for datavisulization
# Seaborn-also used for datavisulization.its like a wrapper on matplotlib which makes it more interactive.

# %%
#installing important libraries
# !pip install numpy pandas seaborn matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# Structre of library is library-module-submodule-prewritten functions

# %%
#import important libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Creating a numpy array
arr = np.array([1, 2, 3, 4, 5])
print('Array :\n', arr)
print('Shape :', arr.shape)
print('Type :', type(arr))
print('Data Type :', arr.dtype)
print('Number of dimensions :', arr.ndim)
print('Size :', arr.size)
# Out:
# Array :
#  [1 2 3 4 5]
# Shape : (5,)
# Type : <class 'numpy.ndarray'>
# Data Type : int64
# Number of dimensions : 1
# Size : 5

# %%
'''
Numpy arrays are compared with Python Lists on two points ->
(1) Size -> Numpy arrays take less space than Python lists
(2) Performance -> Numpy arrays are faster than Python lists
'''
# Out:
# '\nNumpy arrays are compared with Python Lists on two points ->\n(1) Size -> Numpy arrays take less space than Python lists\n(2) Performance -> Numpy arrays are faster than Python lists\n'

# %%
# Size Comparison
import sys

# Declaring a list of 1000 elements
S = range(1000)

# Output
print('Size of each element of list in bytes :', sys.getsizeof(S))
print('Size of the whole list in bytes :', sys.getsizeof(S) * len(S))

# Declaring a numpy array
D = np.arange(1000)

# Output
print('Size of each element of the numpy array in bytes :', D.itemsize)
print('Size of the whole numpy array in bytes :', D.size * D.itemsize)
# Out:
# Size of each element of list in bytes : 48
# Size of the whole list in bytes : 48000
# Size of each element of the numpy array in bytes : 8
# Size of the whole numpy array in bytes : 8000

# %%
48000/8000
# Out:
# 6.0

# %%
# Numpy arrays (in this laptop) are consuming 6 times less space than Python Lists

# %%
# Performance Comparison
import time

# Declaring size
size = 1000000

# Declaring two lists
L1 = range(size)
L2 = range(size)

# Declaring two numpy arrays
A1 = np.arange(size)
A2 = np.arange(size)

# Capturing the time before the operation
start = time.time()

# Multiplying the elements
result = [(x * y) for x, y in zip(L1, L2)]

# Capturing the time after the operation
print('Time taken by Lists to perform multiplication :', (time.time() - start) * 1000, 'ms')

# Capturin the time before the operation
start = time.time()

# Multiplying the elements
result = A1 * A2

# Capturing the time after the operation
print('Time taken by Numpy Arrays to perform multiplication :', (time.time() - start) * 1000, 'ms')
# Out:
# Time taken by Lists to perform multiplication : 142.34590530395508 ms
# Time taken by Numpy Arrays to perform multiplication : 20.1570987701416 ms

# %%
187.483549118042/39.72148895263672
# Out:
# 4.719952702216033

# %%
# Numpy Arrays are 4.72 times faster (in this laptop) than Python lists

# %%
# Numpy arrays are homogenous
arr = np.array([1, 2.0, 'Numpy'])
print('Array :\n', arr)
print('Data Type :', arr.dtype)
# Out:
# Array :
#  ['1' '2.0' 'Numpy']
# Data Type : <U32

# %%
# <U32 means that each element will have less than 32 unicode characters in it

# %%
# Numpy arrays are homogenous
arr = np.array([1, 2.0, 5.7])
print('Array :\n', arr)
print('Data Type :', arr.dtype)
# Out:
# Array :
#  [1.  2.  5.7]
# Data Type : float64

# %%
#since float is in upper to integer in heirarchy.so all the element will convert in float.

# %%
#Random module

# %%
#np.random.rand()-is used to create an array of random values in the range (0,1)
np.random.rand(3,4)
# Out:
# array([[0.27042644, 0.50489586, 0.5224637 , 0.69157584],
#        [0.48144401, 0.54278632, 0.20832857, 0.68218031],
#        [0.08038836, 0.26112387, 0.52640797, 0.20908247]])

# %%
#(3,4)is shape of datatype.

# %%
#np.random.randn() is used to create a array with random normal values whose mean is zero and standard deviation is one.

# %%
np.random.randn(3,4)
# Out:
# array([[ 1.50034191, -1.2354813 ,  0.59750837,  1.65080338],
#        [-0.92697735, -1.92877704,  0.26912664, -0.98312008],
#        [-1.11741619, -1.31195115,  0.54574002, -0.73360153]])

# %%
# np.random.randint() -> used to create an array of random integers
np.random.randint(low = 1, high = 100, size = (3, 4))
# Out:
# array([[51, 16, 28, 50],
#        [59, 72,  9, 37],
#        [ 7, 33, 12, 76]])

# %%
# Low value may be included but High value is never included.

# %%
# Creating an array
arr = np.random.randint(low = 1, high = 100, size = (3, 4))
print('Array :\n', arr)
# Out:
# Array :
#  [[72 78 88 25]
#  [ 6 66  2 93]
#  [39 79 44 53]]

# %%
#Accessing the elements of array by index
print(arr[0])
print(arr[0][1])
print(arr[0, 1])
# Out:
# [72 78 88 25]
# 78
# 78

# %%
#Accessing the elements of array by index
print(arr[2])
print(arr[2, 3])
# Out:
# [39 79 44 53]
# 53

# %%
# Creating an array
arr = np.random.randint(low = 1, high = 100, size = (5, 7))
print('Array :\n', arr)
print('Shape :', arr.shape)
# Out:
# Array :
#  [[60 34 39 65 80 38 53]
#  [57 16 65 60 94 13 25]
#  [68 15 56 61 85 71 10]
#  [13 81 89 93 50 70 53]
#  [96 37 80 47 12 61 50]]
# Shape : (5, 7)

# %%
#slicing of the array
print(arr[2:,3:])
# Out:
# [[61 85 71 10]
#  [93 50 70 53]
#  [47 12 61 50]]

# %%
#slicing of the array
print(arr[2:4,3:5])
# Out:
# [[61 85]
#  [93 50]]

# %%
#Pandas

# %% [markdown]
# # We use pd.Nan for time series.
# for number we use nan(100,200,300)
# otherwise we use none(name)

# %%
#Removing null values
#creating dataset
d1={
    'Name':['pankaj','suresh','ritesh'],
    'ID':[1,2,3],
    'Role':[100, 200, np.nan],
    'Salary':['CEO', np.nan,pd.NaT]
}
df=pd.DataFrame(d1)
print('Actual DataFrame :\n', df)

# Removing the NA Values
df = df.dropna()
print('\nDataFrame after removing the NA Values :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID   Role Salary
# 0  pankaj   1  100.0    CEO
# 1  suresh   2  200.0    NaN
# 2  ritesh   3    NaN    NaT
#
# DataFrame after removing the NA Values :
#       Name  ID   Role Salary
# 0  pankaj   1  100.0    CEO

# %%
# Removing NA Values
# Creating the dataset
d1 = {
    'Name' : ['Pankaj', 'Meghna', 'David', 'Lisa'],
    'ID' : [1, 2, 3, 4],
    'Salary' : [100, 200, np.nan, pd.NaT],
    'Role' : ['CEO', None, np.nan, pd.NaT]
}

df = pd.DataFrame(d1)
print('Actual DataFrame :\n', df)

# Removing the NA Values
df = df.dropna(how='all')
print('\nDataFrame after removing the NA Values :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID Salary  Role
# 0  Pankaj   1    100   CEO
# 1  Meghna   2    200  None
# 2   David   3    NaN   NaN
# 3    Lisa   4    NaT   NaT
#
# DataFrame after removing the NA Values :
#       Name  ID Salary  Role
# 0  Pankaj   1    100   CEO
# 1  Meghna   2    200  None
# 2   David   3    NaN   NaN
# 3    Lisa   4    NaT   NaT

# %%
#how = 'all' is default value..it will drop all the row who are having all rows having null values'

# %%
# Removing NA Values
# Creating the dataset
d1 = {
    'Name' : ['Pankaj', 'Meghna', 'David', 'Lisa'],
    'ID' : [1, 2, 3, 4],
    'Salary' : [100, 200, np.nan, pd.NaT],
    'Role' : ['CEO', None, np.nan, pd.NaT]
}

df = pd.DataFrame(d1)
print('Actual DataFrame :\n', df)

# Removing the NA Values
df = df.dropna(how='any')
print('\nDataFrame after removing the NA Values :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID Salary  Role
# 0  Pankaj   1    100   CEO
# 1  Meghna   2    200  None
# 2   David   3    NaN   NaN
# 3    Lisa   4    NaT   NaT
#
# DataFrame after removing the NA Values :
#       Name  ID Salary Role
# 0  Pankaj   1    100  CEO

# %%
#when we use inplace=true then varible having dataframe gets change ...doesnt change the actual dataset.this
command change the actual dataset.
# Out:
#   File "/tmp/ipython-input-55-1111781047.py", line 2
#     command change the actual dataset.
#             ^
# SyntaxError: invalid syntax

# %%
# Removing NA Values
# Creating the dataset
d1 = {
    'Name' : ['Pankaj', 'Meghna', 'David', 'Lisa'],
    'ID' : [1, 2, 3, 4],
    'Salary' : [100, 200, 300, None],
    'Role' : ['CEO', 'CTO', 'CFO','CMO']
}

df = pd.DataFrame(d1)
print('Actual DataFrame :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID  Salary Role
# 0  Pankaj   1   100.0  CEO
# 1  Meghna   2   200.0  CTO
# 2   David   3   300.0  CFO
# 3    Lisa   4     NaN  CMO

# %%
#getting an idea about null values
df.isnull().sum().any()
# Out:
# np.True_

# %%
# True means that there are NULL values in the dataframe
# False means that there are no NULL values in the dataframe

# %%
# Getting an idea about columnwise sum of NULL values
df.isnull().sum()
# Out:
# Name      0
# ID        0
# Salary    1
# Role      0
# dtype: int64

# %%
# The above code will give you column wis sum of NULL values
# Salary 1 means that there is 1 NULL value in salary column

# %%
#imputation
df['Salary']=df['Salary'].fillna(df['Salary'].median())
print(df)
# Out:
#      Name  ID  Salary Role
# 0  Pankaj   1   100.0  CEO
# 1  Meghna   2   200.0  CTO
# 2   David   3   300.0  CFO
# 3    Lisa   4   200.0  CMO

# %%
# Getting an idea whether there is any NULL value
df.isnull().sum().any()
# Out:
# np.False_

# %%
# False means that there are no NULL values in the dataframe

# %%
# Getting an idea about columnwise sum of NULL values
df.isnull().sum()
# Out:
# Name      0
# ID        0
# Salary    0
# Role      0
# dtype: int64

# %%
# MinmaxScaler is used to convert all the numerical column into range(0,1)...formula is x1!=x1-xmin/xmax-xmin...basically
when there are so many columns like age,salary so we know the gist but ml model doesnt know so we use this
and standardscaler ,formula for this is x1!=x1-mean/std deviation.In StandardScaler mean is bought to zero
and std deviation is bought to one.

# %%
# MinMaxScaler
# Creating the dataset
d1 = {
    'Name' : ['Pankaj', 'Meghna', 'David', 'Lisa'],
    'ID' : [1, 2, 3, 4],
    'Salary' : [100, 200, 300, 400],
    'Role' : ['CEO', 'CTO', 'CFO', 'CMO']
}

df = pd.DataFrame(d1)
print('Actual DataFrame :\n', df)

# Importing the scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Salary'] = scaler.fit_transform(np.array(df['Salary']).reshape(-1, 1))
print('\nDataFrame after MinMaxScaler :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID  Salary Role
# 0  Pankaj   1     100  CEO
# 1  Meghna   2     200  CTO
# 2   David   3     300  CFO
# 3    Lisa   4     400  CMO
#
# DataFrame after MinMaxScaler :
#       Name  ID    Salary Role
# 0  Pankaj   1  0.000000  CEO
# 1  Meghna   2  0.333333  CTO
# 2   David   3  0.666667  CFO
# 3    Lisa   4  1.000000  CMO

# %%
# StandardScaler
# Creating the dataset
d1 = {
    'Name' : ['Pankaj', 'Meghna', 'David', 'Lisa'],
    'ID' : [1, 2, 3, 4],
    'Salary' : [100, 200, 300, 400],
    'Role' : ['CEO', 'CTO', 'CFO', 'CMO']
}

df = pd.DataFrame(d1)
print('Actual DataFrame :\n', df)

# Importing the scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['Salary'] = scaler.fit_transform(np.array(df['Salary']).reshape(-1, 1))
print('\nDataFrame after StandardScaler :\n', df)
# Out:
# Actual DataFrame :
#       Name  ID  Salary Role
# 0  Pankaj   1     100  CEO
# 1  Meghna   2     200  CTO
# 2   David   3     300  CFO
# 3    Lisa   4     400  CMO
#
# DataFrame after StandardScaler :
#       Name  ID    Salary Role
# 0  Pankaj   1 -1.341641  CEO
# 1  Meghna   2 -0.447214  CTO
# 2   David   3  0.447214  CFO
# 3    Lisa   4  1.341641  CMO

# %%
# Encoding -> process of convertign categorical data into numbers

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder

# Creating the initial dataframe
bridge_types = ['Arch', 'Beam', 'Truss', 'Cantilever', 'Tied Arch', 'Suspension', 'Cable']
bridge_df = pd.DataFrame(bridge_types, columns = ['Bridge_Types'])
print('Actual DataFrame :\n', bridge_df)

# Creating the label encoder object
label_encoder = LabelEncoder()
bridge_df['Bridge_Types_Cat'] = label_encoder.fit_transform(bridge_df['Bridge_Types'])
print('\nDataFrame after label encoding :\n', bridge_df)
# Out:
# Actual DataFrame :
#    Bridge_Types
# 0         Arch
# 1         Beam
# 2        Truss
# 3   Cantilever
# 4    Tied Arch
# 5   Suspension
# 6        Cable
#
# DataFrame after label encoding :
#    Bridge_Types  Bridge_Types_Cat
# 0         Arch                 0
# 1         Beam                 1
# 2        Truss                 6
# 3   Cantilever                 3
# 4    Tied Arch                 5
# 5   Suspension                 4
# 6        Cable                 2

# %%
#the problem with labelencoding is it give arch to 0 and beam to 1..mean give more weightage to beam then arch which is not true
so we prefer to use one hot encoding.
# Out:
#   File "/tmp/ipython-input-67-316228964.py", line 2
#     so we prefer to use one hot encoding.
#        ^
# SyntaxError: invalid syntax

# %%
# One Hot Encoding
# Creating the initial dataframe
bridge_types = ['Arch', 'Beam', 'Truss', 'Cantilever', 'Tied Arch', 'Suspension', 'Cable']
bridge_df = pd.DataFrame(bridge_types, columns = ['Bridge_Types'])
print('Actual DataFrame :\n', bridge_df)
one_hot_encoded = pd.get_dummies(bridge_df, columns = ['Bridge_Types'])
one_hot_encoded.replace({True : 1, False : 0}, inplace = True)
print('\nDataFrame after one hot encoding :\n')
one_hot_encoded.head()
# Out:
# Actual DataFrame :
#    Bridge_Types
# 0         Arch
# 1         Beam
# 2        Truss
# 3   Cantilever
# 4    Tied Arch
# 5   Suspension
# 6        Cable
#
# DataFrame after one hot encoding :
# /tmp/ipython-input-68-1320836742.py:7: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   one_hot_encoded.replace({True : 1, False : 0}, inplace = True)
#    Bridge_Types_Arch  Bridge_Types_Beam  Bridge_Types_Cable  \
# 0                  1                  0                   0
# 1                  0                  1                   0
# 2                  0                  0                   0
# 3                  0                  0                   0
# 4                  0                  0                   0
#
#    Bridge_Types_Cantilever  Bridge_Types_Suspension  Bridge_Types_Tied Arch  \
# 0                        0                        0                       0
# 1                        0                        0                       0
# 2                        0                        0                       0
# 3                        1                        0                       0
# 4                        0                        0                       1
#
#    Bridge_Types_Truss
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0

# %%
#datavisualisation is done on data so that data can be easily understandable by human brain.

# %%
#Datavisulisation

# %%
#scatterplot-is used when there is 2 numerical columns.
#Creating the data
X=[34,56,78,89,32,54,23,72,90]
Y=[85,54,72,76,89,45,26,12,20]
#Plotting the scatter
plt.figure(figsize=(5,3))
plt.scatter(X,Y,c='red')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.show()

# %%
# line plot tells the trend of the data.
# Line Plot
# Creating the data
year = [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
unemployment_rate = [9.8, 12, 8, 7.2, 6.9, 7, 6.5, 6.2, 5.5, 6.3, 9.9]

# Plot
plt.figure(figsize = (5, 3))
plt.plot(year, unemployment_rate, c = 'red')
plt.title('Line Plot')
plt.xlabel('Year')
plt.ylabel('Unemployment Rate')
plt.show()

# %%
# Bar chart is used when there is one categorical column and one numerical column
# Bar Chart
# Creating the data
data = {
    'C' : 20,
    'C++' : 15,
    'Java' : 30,
    'Python' : 35
}

# Plotting the bar chart
plt.figure(figsize = (5, 3))
plt.bar(data.keys(), data.values(), color = 'green', width = 0.6)
plt.title('Bar Chart')
plt.xlabel('Programming Languages')
plt.ylabel('Popularity')
plt.show()

# %%
#loading an inbuild dataset in seaborn library
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#countplot-its a barplot but it counts the no of categories.Yaxises is always a count in countplot.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5,3))
sns.countplot(x='day',data=df,color='red')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
#histogram,kde-kernal density curve which gives density curve if true
plt.figure(figsize=(5,3))
sns.histplot(df['total_bill'],color='green',kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# Creating the data
labels = ['Python', 'C++', 'Java', 'Ruby']
sizes = [215, 130, 245, 210]

# Plotting the pie chart
plt.figure(figsize = (5, 3))
plt.pie(sizes, labels = labels, autopct = '%.2f%%')
plt.title('Pie Chart')
plt.show()

# %%
....piechart give an idea about composition of data[autopct = '%.2f%%'gives automatic percentage..
.%.2f% gives value till two decimal points]...[5,3-size in inches]

# %%
# Heatmap -> Colored Table
# Creating the data
import numpy as np
data = np.random.randint(low = 1, high = 100, size = (10, 10))
print('The data to be plotted :\n', data)
# Out:
# The data to be plotted :
#  [[85 20 39 66 65 91 84 64 59 17]
#  [73  1 36 83 64 49 24  1 16 61]
#  [61 10 46 95 85 86 68 15 80 96]
#  [76 61 98 34  3 58  2 21 49 79]
#  [69 84 21 32 97  3 26 19 15 69]
#  [46 61 99 28 29 54 74 38 13 52]
#  [34 46 70 80 88 92 39 71 92 69]
#  [69 91  3 10 64 81 81 52 26 93]
#  [78 80 59 50 53 18 37 22 76  3]
#  [30 67 56  2 82 49 79 52 42 63]]

# %%
# Heatmap
plt.figure(figsize = (5, 3))
sns.heatmap(data, annot = True, cmap = 'Blues')
# Out:
# <Axes: >

# %%
# Getting the data
exercise = sns.load_dataset('exercise', index_col = 0)
exercise.head()
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest
# 3   2  low fat     90   1 min  rest
# 4   2  low fat     92  15 min  rest

# %%
# catplot
sns.catplot(x = 'time', y = 'pulse', data = exercise, hue = 'kind')

# %%
# distplot() -> used for getting the density curve
plt.figure(figsize = (5, 3))
sns.distplot(exercise['pulse'], kde = True)
# Out:
# /tmp/ipython-input-81-4235370185.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(exercise['pulse'], kde = True)
# <Axes: xlabel='pulse', ylabel='Density'>

# %%
# Getting the 'tips.csv' data
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Pair Plot
sns.pairplot(df, hue = 'day', palette = 'coolwarm')

# %%
# jointplot()
plt.figure(figsize = (5, 3))
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'reg')

# %%
# jointplot()
plt.figure(figsize = (5, 3))
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'scatter')

# %%
# jointplot()
plt.figure(figsize = (5, 3))
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')
